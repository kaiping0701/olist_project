# %%
import pandas as pd 
import os

# %%
os.getcwd() # 取得當前目錄
# Out:
# '/Users/kaiping/Desktop/olist_project/notebooks/learning'

# %%
orders = pd.read_csv("../../data/raw/olist_orders_dataset.csv") # ../..走為專案初始目錄後讀取raw目錄資料
# 相對路徑 
# ..回到上一個目錄
# /進入某個資料夾

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered          2017/10/2 10:56   2017/10/2 11:07
# 1    delivered          2018/7/24 20:41    2018/7/26 3:24
# 2    delivered            2018/8/8 8:38     2018/8/8 8:55
# 3    delivered         2017/11/18 19:28  2017/11/18 19:45
# 4    delivered          2018/2/13 21:18   2018/2/13 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017/10/4 19:55              2017/10/10 21:25
# 1              2018/7/26 14:31                2018/8/7 15:27
# ...

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64
