# %%
a = "a,b,c,d"


a.split(",")
# Out:
# ['a', 'b', 'c', 'd']

# %%
# 1. 默认去除首尾空格
text = "  Hello World  \n"
print(text.strip())  # 输出: "Hello World"

# 2. 去除指定的特定字符
file_path = "www.example.com.cn"
print(file_path.strip("cnm."))  # 输出: "example.co" (首尾包含的 c, n, m, . 都会被去除)
# Out:
# Hello World
# www.example.co

# %%
def _split_cols(s: str) -> list[str]:
    return [c.strip() for c in str(s).split("|") if c.strip()]
s = " order_id |  product_id | | seller_id  "

# %%
_split_cols(s)
# Out:
# ['order_id', 'product_id', 'seller_id']

# %%
nums = [1, 2, 3, 4]
result = []
for i in nums:
	i*=2 
	result.append(i)

# %%
result
# Out:
# [2, 4, 6, 8]

# %%
[i*2 for i in nums]
# Out:
# [2, 4, 6, 8]

# %%
result = []

for x in nums:
	if x%2==0:
		result.append(i*2)



result
# Out:
# [16, 16]

# %%
def _split_cols(s: str) -> list[str]:
    return [c.strip() for c in str(s).split("|") if c.strip()]

# %%
def split_cols: 
    result = []
    for x in str(s).split('|'):
        if x.strip():
            x.strip 
            result.append(x)
